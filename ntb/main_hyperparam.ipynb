# %% [markdown]
# # Preparation stuff

# %% [markdown]
# ## Connect to Drive

# %%
connect_to_drive = False

# %%
#Run command and authorize by popup --> other window
if connect_to_drive:
    from google.colab import drive
    drive.mount('/content/gdrive', force_remount=True)

# %% [markdown]
# ## Install packages

# %%
if connect_to_drive:
    #Install FS code
    # !pip install  --upgrade --force-reinstall git+https://github.com/federicosiciliano/easy_lightning.git

    # !pip install pytorch_lightning

# %% [markdown]
# ## IMPORTS

# %%
#Put all imports here
import numpy as np
from copy import deepcopy
import os
import sys

# %% [markdown]
# ## Define paths

# %%
#every path should start from the project folder:
project_folder = "../"
if connect_to_drive:
    project_folder = "/content/gdrive/Shareddrives/<SharedDriveName>" #Name of SharedDrive folder
    #project_folder = "/content/gdrive/MyDrive/<MyDriveName>" #Name of MyDrive folder

#Config folder should contain hyperparameters configurations
cfg_folder = os.path.join(project_folder,"cfg")

#Data folder should contain raw and preprocessed data
data_folder = os.path.join(project_folder,"data")
raw_data_folder = os.path.join(data_folder,"raw")
processed_data_folder = os.path.join(data_folder,"processed")

#Source folder should contain all the (essential) source code
source_folder = os.path.join(project_folder,"src")

#The out folder should contain all outputs: models, results, plots, etc.
out_folder = os.path.join(project_folder,"out")
img_folder = os.path.join(out_folder,"img")

# %% [markdown]
# ## Import own code

# %%
#To import from src:

#attach the source folder to the start of sys.path
sys.path.insert(0, project_folder)

#import from src directory
# from src import ??? as additional_module
import easy_rec as additional_module #REMOVE THIS LINE IF IMPORTING OWN ADDITIONAL MODULE

import easy_exp, easy_rec, easy_torch #easy_data

# %% [markdown]
# # MAIN

# %% [markdown]
# ## Train

# %% [markdown]
# ### Data

# %%
cfg = easy_exp.cfg.load_configuration("config_rec")

# %%
from ray import tune

# %%
def prepare_raytune_config(cfg):
    raytune_cfg = {}
    for parameter_name, v in cfg["__exp__"]["__sweep__"]["parameters"].items():
        if "tune" in v:
            raytune_cfg[parameter_name] = getattr(tune, v["tune"]["name"])(**v["tune"]["params"])
    return raytune_cfg

# %%
raytune_cfg = prepare_raytune_config(cfg)

# %%
#from ray.train.lightning import RayDDPStrategy, RayLightningEnvironment, RayTrainReportCallback, prepare_trainer

# %%
# cfg["model"]["trainer_params"]["strategy"] = RayDDPStrategy()
# #cfg["model"]["trainer_params"]["callbacks"].append(lambda : RayTrainReportCallback())
# cfg["model"]["trainer_params"]["plugins"] = cfg["model"]["trainer_params"].get("plugins", []) + [RayLightningEnvironment()]

# %%
def run_config(cfg, if_exp_found=None, raytune=False):
    # exp_found
    # skip --> skip the experiment
    # load --> load the experiment
    # if not load nor skip, reruns the experiment completely

    exp_found, experiment_id = easy_exp.exp.get_set_experiment_id(cfg)
    #print("Experiment already found:", exp_found, "----> The experiment id is:", experiment_id)

    if exp_found and if_exp_found == "skip":
        #print("Skipping experiment")
        return
    
    # Save experiment (done here cause Early stopping with Tune schedulers may not run anything after training)
    easy_exp.exp.save_experiment(cfg)

    data, maps = easy_rec.preparation.prepare_rec_data(cfg)

    loaders = easy_rec.preparation.prepare_rec_dataloaders(cfg, data, maps)

    main_module = easy_rec.preparation.prepare_rec_model(cfg, maps)

    trainer = easy_torch.preparation.complete_prepare_trainer(cfg, experiment_id, additional_module=easy_rec, raytune=raytune)

    model = easy_torch.preparation.complete_prepare_model(cfg, main_module, additional_module=easy_rec)

    if exp_found and if_exp_found == "load":
        easy_torch.process.load_model(trainer, model, experiment_id)

    easy_torch.process.test_model(trainer, model, loaders, test_key=["val","test","train"])

    # Train the model using the prepared trainer, model, and data loaders
    easy_torch.process.train_model(trainer, model, loaders, val_key=["val","test"])

    # Early stopping with Tune schedulers may not run anything after training

# %%
def run_raytune_cfg(raytune_cfg, cfg, if_exp_found=None):
    complete_cfg = deepcopy(cfg)
    complete_cfg.update(raytune_cfg)

    # save complete_cfg to a file

    run_config(complete_cfg, if_exp_found, raytune=True)

# %%
# checkpoint_data = {
#     "epoch": epoch,
#     "net_state_dict": net.state_dict(),
#     "optimizer_state_dict": optimizer.state_dict(),
# }
# with tempfile.TemporaryDirectory() as checkpoint_dir:
#     data_path = Path(checkpoint_dir) / "data.pkl"
#     with open(data_path, "wb") as fp:
#         pickle.dump(checkpoint_data, fp)

#     checkpoint = Checkpoint.from_directory(checkpoint_dir)
#     train.report(
#         {"loss": val_loss / val_steps, "accuracy": correct / total},
#         checkpoint=checkpoint,
#     )

# %%
max_num_epochs = cfg["model"]["trainer_params"]["max_epochs"]
scheduler = tune.schedulers.ASHAScheduler(
        metric="val_NDCG_@10/dataloader_idx_0",
        mode="min",
        max_t=max_num_epochs,
        grace_period=1,
        reduction_factor=2)

# %%
from ray.train.torch import TorchTrainer
from ray.train import ScalingConfig#, RunConfig, CheckpointConfig

scaling_config = ScalingConfig(
    num_workers=2, use_gpu=True, resources_per_worker={"CPU": 8, "GPU": 1}
)

# run_config = RunConfig(
#     checkpoint_config=CheckpointConfig(
#         num_to_keep=2,
#         checkpoint_score_attribute="ptl/val_accuracy",
#         checkpoint_score_order="max",
#     ),
# )

# Define a TorchTrainer without hyper-parameters for Tuner
ray_trainer = TorchTrainer(
    lambda x: run_raytune_cfg(x, cfg),
    scaling_config=scaling_config,
    # run_config=run_config,
)

# %%
os.environ["RAY_CHDIR_TO_TRIAL_DIR"] = "0" #To avoid changing working directory

# %%
tuner = tune.Tuner(
    ray_trainer,
    param_space={"train_loop_config": raytune_cfg},
    tune_config=tune.TuneConfig(
        # metric="val_NDCG_@10/dataloader_idx_0",
        # mode="max",
        num_samples=100,
        scheduler=scheduler,
        time_budget_s=40, #seconds #May raise WARNING Failed to fetch metrics for
    ),
)

results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-12-24 17:35:44</td></tr>
# <tr><td>Running for: </td><td>00:00:10.86        </td></tr>
# <tr><td>Memory:      </td><td>6.6/124.9 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=0<br>Bracket: Iter 256.000: None | Iter 128.000: None | Iter 64.000: None | Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None<br>Logical resource usage: 0/32 CPUs, 0/2 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
#   Number of errored trials: 1<br><table>
# <thead>
# <tr><th>Trial name              </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                                                                                                                                                    </th></tr>
# </thead>
# <tbody>
# <tr><td>TorchTrainer_18ceb_00000</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-12-24_17-35-32_668617_2176674/artifacts/2024-12-24_17-35-33/TorchTrainer_2024-12-24_17-35-32/driver_artifacts/TorchTrainer_18ceb_00000_0_model_optimizer_params_lr=0.0491,model_rec_model_dropout_rate=0.3416,model_rec_model_num_blocks=1_2024-12-24_17-35-33/error.txt</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name              </th><th>status  </th><th>loc                 </th><th style="text-align: right;">           ...loop_config/model
# .optimizer.params.lr</th><th style="text-align: right;">            ...p_config/model.re
# c_model.dropout_rate</th><th style="text-align: right;">  ...oop_config/model.
# rec_model.num_blocks</th></tr>
# </thead>
# <tbody>
# <tr><td>TorchTrainer_18ceb_00001</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0242003 </td><td style="text-align: right;">0.195515   </td><td style="text-align: right;">1</td></tr>
# <tr><td>TorchTrainer_18ceb_00002</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0770719 </td><td style="text-align: right;">0.175685   </td><td style="text-align: right;">1</td></tr>
# <tr><td>TorchTrainer_18ceb_00003</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0499875 </td><td style="text-align: right;">0.418424   </td><td style="text-align: right;">1</td></tr>
# <tr><td>TorchTrainer_18ceb_00004</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0686163 </td><td style="text-align: right;">0.427993   </td><td style="text-align: right;">2</td></tr>
# <tr><td>TorchTrainer_18ceb_00005</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0611673 </td><td style="text-align: right;">0.221484   </td><td style="text-align: right;">2</td></tr>
# <tr><td>TorchTrainer_18ceb_00006</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.095605  </td><td style="text-align: right;">0.321202   </td><td style="text-align: right;">2</td></tr>
# <tr><td>TorchTrainer_18ceb_00007</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.00159042</td><td style="text-align: right;">0.371017   </td><td style="text-align: right;">2</td></tr>
# <tr><td>TorchTrainer_18ceb_00008</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.00965245</td><td style="text-align: right;">0.22153    </td><td style="text-align: right;">2</td></tr>
# <tr><td>TorchTrainer_18ceb_00009</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0865893 </td><td style="text-align: right;">0.304719   </td><td style="text-align: right;">1</td></tr>
# <tr><td>TorchTrainer_18ceb_00010</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0256837 </td><td style="text-align: right;">0.284954   </td><td style="text-align: right;">2</td></tr>
# <tr><td>TorchTrainer_18ceb_00011</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.02147   </td><td style="text-align: right;">0.256246   </td><td style="text-align: right;">1</td></tr>
# <tr><td>TorchTrainer_18ceb_00012</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.00145174</td><td style="text-align: right;">0.0973553  </td><td style="text-align: right;">2</td></tr>
# <tr><td>TorchTrainer_18ceb_00013</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0692587 </td><td style="text-align: right;">0.343173   </td><td style="text-align: right;">1</td></tr>
# <tr><td>TorchTrainer_18ceb_00014</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.00342367</td><td style="text-align: right;">0.0992764  </td><td style="text-align: right;">2</td></tr>
# <tr><td>TorchTrainer_18ceb_00015</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0627699 </td><td style="text-align: right;">0.445211   </td><td style="text-align: right;">2</td></tr>
# <tr><td>TorchTrainer_18ceb_00016</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0237707 </td><td style="text-align: right;">0.141391   </td><td style="text-align: right;">1</td></tr>
# <tr><td>TorchTrainer_18ceb_00017</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0274546 </td><td style="text-align: right;">0.0077518  </td><td style="text-align: right;">1</td></tr>
# <tr><td>TorchTrainer_18ceb_00018</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0158406 </td><td style="text-align: right;">0.315682   </td><td style="text-align: right;">1</td></tr>
# <tr><td>TorchTrainer_18ceb_00019</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0541339 </td><td style="text-align: right;">0.486409   </td><td style="text-align: right;">2</td></tr>
# <tr><td>TorchTrainer_18ceb_00020</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0668412 </td><td style="text-align: right;">0.492953   </td><td style="text-align: right;">2</td></tr>
# <tr><td>TorchTrainer_18ceb_00021</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0732054 </td><td style="text-align: right;">0.312522   </td><td style="text-align: right;">1</td></tr>
# <tr><td>TorchTrainer_18ceb_00022</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.00413069</td><td style="text-align: right;">0.184836   </td><td style="text-align: right;">2</td></tr>
# <tr><td>TorchTrainer_18ceb_00023</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0829095 </td><td style="text-align: right;">0.222459   </td><td style="text-align: right;">2</td></tr>
# <tr><td>TorchTrainer_18ceb_00024</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0268241 </td><td style="text-align: right;">0.000379756</td><td style="text-align: right;">1</td></tr>
# <tr><td>TorchTrainer_18ceb_00025</td><td>PENDING </td><td>                    </td><td style="text-align: right;">0.0798785 </td><td style="text-align: right;">0.199141   </td
# (TorchTrainer pid=2178899) Started distributed worker processes:
# (TorchTrainer pid=2178899) - (node_id=693b4ef5f32c281865f33712464cc92cfa8273adb9eac8865854f014, ip=192.168.1.94, pid=2179139) world_rank=0, local_rank=0, node_rank=0
# (TorchTrainer pid=2178899) - (node_id=693b4ef5f32c281865f33712464cc92cfa8273adb9eac8865854f014, ip=192.168.1.94, pid=2179138) world_rank=1, local_rank=1, node_rank=0
# (RayTrainWorker pid=2179139) Setting up process group for: env:// [rank=0, world_size=2]
# (RayTrainWorker pid=2179139) Ratings data already exists. Skip pre-processing
# (RayTrainWorker pid=2179138) Filtering by minimum number of users per item: 5
# (RayTrainWorker pid=2179138) Filtering by minimum number of items per user: 5
# (RayTrainWorker pid=2179138) Densifying index
# (RayTrainWorker pid=2179138) Splitting: leave_n_out
# (RayTrainWorker pid=2179138) [rank: 1] Seed set to 42
# 2024-12-24 17:35:43,754	ERROR tune_controller.py:1331 -- Trial task failed for trial TorchTrainer_18ceb_00000
# Traceback (most recent call last):
#   File "/home/caldia/recsys-svd/rec_svd/lib/python3.12/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "/home/caldia/recsys-svd/rec_svd/lib/python3.12/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/caldia/recsys-svd/rec_svd/lib/python3.12/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/caldia/recsys-svd/rec_svd/lib/python3.12/site-packages/ray/_private/worker.py", line 2755, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/caldia/recsys-svd/rec_svd/lib/python3.12/site-packages/ray/_private/worker.py", line 906, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_Inner.train() (pid=2178899, ip=192.168.1.94, actor_id=e69572529dfde7bee5058db001000000, repr=TorchTrainer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/caldia/recsys-svd/rec_svd/lib/python3.12/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/caldia/recsys-svd/rec_svd/lib/python3.12/site-packages/ray/train/_internal/utils.py", line 57, in check_for_failure
#     ray.get(object_ref)
#            ^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ray.exceptions.RayTaskError(TypeError): ray::_RayTrainWorker__execute.get_next() (pid=2179138, ip=192.168.1.94, actor_id=678af7413999104827faec9401000000, repr=<ray.train._internal.worker_group.RayTrainWorker object at 0x7bdd3a5c66c0>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/caldia/recsys-svd/rec_svd/lib/python3.12/site-packages/ray/train/_internal/worker_group.py", line 33, in __execute
#     raise skipped from exception_cause(skipped)
#   File "/home/caldia/recsys-svd/rec_svd/lib/python3.12/site-packages/ray/train/_internal/utils.py", line 176, in discard_return_wrapper
#     train_func(*args, **kwargs)
#   File "/tmp/ipykernel_2176674/2282506517.py", line 18, in <lambda>
#   File "/tmp/ipykernel_2176674/3657210523.py", line 7, in run_raytune_cfg
#   File "/tmp/ipykernel_2176674/3183413652.py", line 21, in run_config
#   File "/home/caldia/recsys-svd/rec_svd/lib/python3.12/site-packages/easy_rec/preparation.py", line 51, in prepare_rec_model
#     main_module = rec_torch.create_rec_model(**rec_model_params)#, graph=easy_rec.data_generation_utils.get_graph_representation(data["train_sid"]))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/caldia/recsys-svd/rec_svd/lib/python3.12/site-packages/easy_rec/rec_torch.py", line 567, in create_rec_model
#     return getattr(model_module, name)(**model_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/caldia/recsys-svd/rec_svd/lib/python3.12/site-packages/easy_rec/model/sequential/SASRec.py", line 35, in __init__
#     encoder_layer = torch.nn.TransformerEncoderLayer(emb_size, num_heads, emb_size * 4, dropout_rate,
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/caldia/recsys-svd/rec_svd/lib/python3.12/site-packages/torch/nn/modules/transformer.py", line 712, in __init__
#     self.self_attn = MultiheadAttention(
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/caldia/recsys-svd/rec_svd/lib/python3.12/site-packages/torch/nn/modules/activation.py", line 1054, in __init__
#     if embed_dim <= 0 or num_heads <= 0:
#                          ^^^^^^^^^^^^^^
# TypeError: '<=' not supported between instances of 'dict' and 'int'
# 2024-12-24 17:35:44,667	WARNING tune.py:219 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2024-12-24 17:35:44,671	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/user/ray_results/TorchTrainer_2024-12-24_17-35-32' in 0.0039s.
# 2024-12-24 17:35:44,700	ERROR tune.py:1037 -- Trials did not complete: [TorchTrainer_18ceb_00000]
# 2024-12-24 17:35:44,701	INFO tune.py:1041 -- Total run time: 10.90 seconds (10.85 seconds for the tuning loop).
# 2024-12-24 17:35:44,701	WARNING tune.py:1056 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: Tuner.restore(path="/home/user/ray_results/TorchTrainer_2024-12-24_17-35-32", trainable=...)
# 2024-12-24 17:35:44,711	WARNING experiment_analysis.py:180 -- Failed to fetch metrics for 99 trial(s):
# - TorchTrainer_18ceb_00001: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00001: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00001_1_model_optimizer_params_lr=0.0242,model_rec_model_dropout_rate=0.1955,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00002: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00002: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00002_2_model_optimizer_params_lr=0.0771,model_rec_model_dropout_rate=0.1757,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00003: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00003: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00003_3_model_optimizer_params_lr=0.0500,model_rec_model_dropout_rate=0.4184,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00004: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00004: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00004_4_model_optimizer_params_lr=0.0686,model_rec_model_dropout_rate=0.4280,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00005: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00005: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00005_5_model_optimizer_params_lr=0.0612,model_rec_model_dropout_rate=0.2215,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00006: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00006: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00006_6_model_optimizer_params_lr=0.0956,model_rec_model_dropout_rate=0.3212,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00007: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00007: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00007_7_model_optimizer_params_lr=0.0016,model_rec_model_dropout_rate=0.3710,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00008: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00008: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00008_8_model_optimizer_params_lr=0.0097,model_rec_model_dropout_rate=0.2215,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00009: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00009: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00009_9_model_optimizer_params_lr=0.0866,model_rec_model_dropout_rate=0.3047,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00010: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00010: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00010_10_model_optimizer_params_lr=0.0257,model_rec_model_dropout_rate=0.2850,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00011: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00011: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00011_11_model_optimizer_params_lr=0.0215,model_rec_model_dropout_rate=0.2562,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00012: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00012: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00012_12_model_optimizer_params_lr=0.0015,model_rec_model_dropout_rate=0.0974,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00013: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00013: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00013_13_model_optimizer_params_lr=0.0693,model_rec_model_dropout_rate=0.3432,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00014: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00014: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00014_14_model_optimizer_params_lr=0.0034,model_rec_model_dropout_rate=0.0993,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00015: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00015: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00015_15_model_optimizer_params_lr=0.0628,model_rec_model_dropout_rate=0.4452,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00016: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00016: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00016_16_model_optimizer_params_lr=0.0238,model_rec_model_dropout_rate=0.1414,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00017: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00017: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00017_17_model_optimizer_params_lr=0.0275,model_rec_model_dropout_rate=0.0078,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00018: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00018: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00018_18_model_optimizer_params_lr=0.0158,model_rec_model_dropout_rate=0.3157,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00019: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00019: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00019_19_model_optimizer_params_lr=0.0541,model_rec_model_dropout_rate=0.4864,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00020: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00020: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00020_20_model_optimizer_params_lr=0.0668,model_rec_model_dropout_rate=0.4930,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00021: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00021: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00021_21_model_optimizer_params_lr=0.0732,model_rec_model_dropout_rate=0.3125,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00022: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00022: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00022_22_model_optimizer_params_lr=0.0041,model_rec_model_dropout_rate=0.1848,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00023: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00023: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00023_23_model_optimizer_params_lr=0.0829,model_rec_model_dropout_rate=0.2225,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00024: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00024: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00024_24_model_optimizer_params_lr=0.0268,model_rec_model_dropout_rate=0.0004,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00025: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00025: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00025_25_model_optimizer_params_lr=0.0799,model_rec_model_dropout_rate=0.1991,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00026: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00026: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00026_26_model_optimizer_params_lr=0.0191,model_rec_model_dropout_rate=0.2957,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00027: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00027: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00027_27_model_optimizer_params_lr=0.0802,model_rec_model_dropout_rate=0.2018,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00028: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00028: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00028_28_model_optimizer_params_lr=0.0863,model_rec_model_dropout_rate=0.4315,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00029: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00029: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00029_29_model_optimizer_params_lr=0.0277,model_rec_model_dropout_rate=0.0587,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00030: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00030: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00030_30_model_optimizer_params_lr=0.0681,model_rec_model_dropout_rate=0.2689,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00031: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00031: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00031_31_model_optimizer_params_lr=0.0504,model_rec_model_dropout_rate=0.3937,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00032: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00032: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00032_32_model_optimizer_params_lr=0.0655,model_rec_model_dropout_rate=0.4008,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00033: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00033: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00033_33_model_optimizer_params_lr=0.0015,model_rec_model_dropout_rate=0.1692,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00034: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00034: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00034_34_model_optimizer_params_lr=0.0699,model_rec_model_dropout_rate=0.2473,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00035: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00035: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00035_35_model_optimizer_params_lr=0.0133,model_rec_model_dropout_rate=0.3894,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00036: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00036: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00036_36_model_optimizer_params_lr=0.0936,model_rec_model_dropout_rate=0.0721,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00037: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00037: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00037_37_model_optimizer_params_lr=0.0274,model_rec_model_dropout_rate=0.3939,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00038: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00038: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00038_38_model_optimizer_params_lr=0.0881,model_rec_model_dropout_rate=0.3827,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00039: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00039: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00039_39_model_optimizer_params_lr=0.0368,model_rec_model_dropout_rate=0.2605,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00040: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00040: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00040_40_model_optimizer_params_lr=0.0919,model_rec_model_dropout_rate=0.1441,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00041: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00041: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00041_41_model_optimizer_params_lr=0.0218,model_rec_model_dropout_rate=0.2723,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00042: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00042: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00042_42_model_optimizer_params_lr=0.0474,model_rec_model_dropout_rate=0.0578,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00043: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00043: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00043_43_model_optimizer_params_lr=0.0995,model_rec_model_dropout_rate=0.2314,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00044: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00044: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00044_44_model_optimizer_params_lr=0.0184,model_rec_model_dropout_rate=0.2592,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00045: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00045: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00045_45_model_optimizer_params_lr=0.0374,model_rec_model_dropout_rate=0.1196,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00046: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00046: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00046_46_model_optimizer_params_lr=0.0619,model_rec_model_dropout_rate=0.0366,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00047: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00047: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00047_47_model_optimizer_params_lr=0.0374,model_rec_model_dropout_rate=0.2346,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00048: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00048: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00048_48_model_optimizer_params_lr=0.0547,model_rec_model_dropout_rate=0.2857,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00049: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00049: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00049_49_model_optimizer_params_lr=0.0884,model_rec_model_dropout_rate=0.2993,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00050: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00050: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00050_50_model_optimizer_params_lr=0.0323,model_rec_model_dropout_rate=0.3602,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00051: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00051: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00051_51_model_optimizer_params_lr=0.0852,model_rec_model_dropout_rate=0.4705,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00052: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00052: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00052_52_model_optimizer_params_lr=0.0847,model_rec_model_dropout_rate=0.4215,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00053: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00053: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00053_53_model_optimizer_params_lr=0.0436,model_rec_model_dropout_rate=0.2241,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00054: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00054: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00054_54_model_optimizer_params_lr=0.0999,model_rec_model_dropout_rate=0.3587,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00055: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00055: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00055_55_model_optimizer_params_lr=0.0178,model_rec_model_dropout_rate=0.2469,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00056: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00056: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00056_56_model_optimizer_params_lr=0.0227,model_rec_model_dropout_rate=0.4996,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00057: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00057: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00057_57_model_optimizer_params_lr=0.0417,model_rec_model_dropout_rate=0.0204,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00058: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00058: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00058_58_model_optimizer_params_lr=0.0464,model_rec_model_dropout_rate=0.3989,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00059: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00059: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00059_59_model_optimizer_params_lr=0.0933,model_rec_model_dropout_rate=0.3052,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00060: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00060: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00060_60_model_optimizer_params_lr=0.0890,model_rec_model_dropout_rate=0.4736,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00061: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00061: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00061_61_model_optimizer_params_lr=0.0592,model_rec_model_dropout_rate=0.3849,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00062: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00062: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00062_62_model_optimizer_params_lr=0.0226,model_rec_model_dropout_rate=0.3879,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00063: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00063: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00063_63_model_optimizer_params_lr=0.0917,model_rec_model_dropout_rate=0.3291,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00064: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00064: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00064_64_model_optimizer_params_lr=0.0472,model_rec_model_dropout_rate=0.3089,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00065: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00065: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00065_65_model_optimizer_params_lr=0.0417,model_rec_model_dropout_rate=0.2543,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00066: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00066: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00066_66_model_optimizer_params_lr=0.0567,model_rec_model_dropout_rate=0.0200,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00067: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00067: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00067_67_model_optimizer_params_lr=0.0981,model_rec_model_dropout_rate=0.4588,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00068: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00068: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00068_68_model_optimizer_params_lr=0.0370,model_rec_model_dropout_rate=0.3058,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00069: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00069: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00069_69_model_optimizer_params_lr=0.0564,model_rec_model_dropout_rate=0.1723,model_rec_model_num_blocks=2_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00070: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00070: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00070_70_model_optimizer_params_lr=0.0974,model_rec_model_dropout_rate=0.1176,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00071: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00071: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00071_71_model_optimizer_params_lr=0.0637,model_rec_model_dropout_rate=0.3568,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00072: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00072: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00072_72_model_optimizer_params_lr=0.0960,model_rec_model_dropout_rate=0.2017,model_rec_model_num_blocks=1_2024-12-24_17-35-33')
# - TorchTrainer_18ceb_00073: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00073: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00073_73_model_optimizer_params_lr=0.0700,model_rec_model_dropout_rate=0.3144,model_rec_model_num_blocks=2_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00074: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00074: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00074_74_model_optimizer_params_lr=0.0883,model_rec_model_dropout_rate=0.0491,model_rec_model_num_blocks=2_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00075: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00075: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00075_75_model_optimizer_params_lr=0.0262,model_rec_model_dropout_rate=0.2939,model_rec_model_num_blocks=1_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00076: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00076: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00076_76_model_optimizer_params_lr=0.0214,model_rec_model_dropout_rate=0.3671,model_rec_model_num_blocks=1_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00077: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00077: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00077_77_model_optimizer_params_lr=0.0865,model_rec_model_dropout_rate=0.4126,model_rec_model_num_blocks=1_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00078: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00078: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00078_78_model_optimizer_params_lr=0.0836,model_rec_model_dropout_rate=0.2910,model_rec_model_num_blocks=1_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00079: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00079: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00079_79_model_optimizer_params_lr=0.0319,model_rec_model_dropout_rate=0.1543,model_rec_model_num_blocks=1_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00080: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00080: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00080_80_model_optimizer_params_lr=0.0888,model_rec_model_dropout_rate=0.2066,model_rec_model_num_blocks=1_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00081: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00081: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00081_81_model_optimizer_params_lr=0.0876,model_rec_model_dropout_rate=0.2187,model_rec_model_num_blocks=2_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00082: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00082: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00082_82_model_optimizer_params_lr=0.0329,model_rec_model_dropout_rate=0.3542,model_rec_model_num_blocks=2_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00083: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00083: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00083_83_model_optimizer_params_lr=0.0695,model_rec_model_dropout_rate=0.4738,model_rec_model_num_blocks=2_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00084: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00084: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00084_84_model_optimizer_params_lr=0.0766,model_rec_model_dropout_rate=0.4081,model_rec_model_num_blocks=2_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00085: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00085: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00085_85_model_optimizer_params_lr=0.0794,model_rec_model_dropout_rate=0.1588,model_rec_model_num_blocks=2_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00086: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00086: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00086_86_model_optimizer_params_lr=0.0239,model_rec_model_dropout_rate=0.1440,model_rec_model_num_blocks=1_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00087: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00087: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00087_87_model_optimizer_params_lr=0.0299,model_rec_model_dropout_rate=0.3471,model_rec_model_num_blocks=1_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00088: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00088: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00088_88_model_optimizer_params_lr=0.0140,model_rec_model_dropout_rate=0.2800,model_rec_model_num_blocks=2_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00089: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00089: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00089_89_model_optimizer_params_lr=0.0729,model_rec_model_dropout_rate=0.2123,model_rec_model_num_blocks=1_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00090: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00090: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00090_90_model_optimizer_params_lr=0.0159,model_rec_model_dropout_rate=0.4691,model_rec_model_num_blocks=1_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00091: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00091: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00091_91_model_optimizer_params_lr=0.0616,model_rec_model_dropout_rate=0.1202,model_rec_model_num_blocks=2_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00092: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00092: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00092_92_model_optimizer_params_lr=0.0374,model_rec_model_dropout_rate=0.1382,model_rec_model_num_blocks=2_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00093: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00093: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00093_93_model_optimizer_params_lr=0.0095,model_rec_model_dropout_rate=0.1968,model_rec_model_num_blocks=1_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00094: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00094: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00094_94_model_optimizer_params_lr=0.0802,model_rec_model_dropout_rate=0.1039,model_rec_model_num_blocks=1_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00095: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00095: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00095_95_model_optimizer_params_lr=0.0618,model_rec_model_dropout_rate=0.1182,model_rec_model_num_blocks=1_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00096: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00096: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00096_96_model_optimizer_params_lr=0.0543,model_rec_model_dropout_rate=0.0911,model_rec_model_num_blocks=1_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00097: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00097: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00097_97_model_optimizer_params_lr=0.0575,model_rec_model_dropout_rate=0.3703,model_rec_model_num_blocks=2_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00098: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00098: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00098_98_model_optimizer_params_lr=0.0447,model_rec_model_dropout_rate=0.1087,model_rec_model_num_blocks=1_2024-12-24_17-35-34')
# - TorchTrainer_18ceb_00099: FileNotFoundError('Could not fetch metrics for TorchTrainer_18ceb_00099: both result.json and progress.csv were not found at /home/user/ray_results/TorchTrainer_2024-12-24_17-35-32/TorchTrainer_18ceb_00099_99_model_optimizer_params_lr=0.0166,model_rec_model_dropout_rate=0.3166,model_rec_model_num_blocks=2_2024-12-24_17-35-34')

# %%
results
# Out:
# ResultGrid<[
#   Result(
#     metrics={'val_loss/dataloader_idx_0': 0.3252166211605072, 'val_Precision_@5/dataloader_idx_0': 0.20000000298023224, 'val_Precision_@10/dataloader_idx_0': 0.10000000149011612, 'val_Precision_@20/dataloader_idx_0': 0.05000000074505806, 'val_Recall_@5/dataloader_idx_0': 1.0, 'val_Recall_@10/dataloader_idx_0': 1.0, 'val_Recall_@20/dataloader_idx_0': 1.0, 'val_F1_@5/dataloader_idx_0': 0.33333075046539307, 'val_F1_@10/dataloader_idx_0': 0.18181663751602173, 'val_F1_@20/dataloader_idx_0': 0.09523725509643555, 'val_MAP_@5/dataloader_idx_0': 0.44430258870124817, 'val_MAP_@10/dataloader_idx_0': 0.2867147624492645, 'val_MAP_@20/dataloader_idx_0': 0.17679595947265625, 'val_NDCG_@5/dataloader_idx_0': 0.9771838784217834, 'val_NDCG_@10/dataloader_idx_0': 0.9771838784217834, 'val_NDCG_@20/dataloader_idx_0': 0.9771838784217834, 'val_MRR_@5/dataloader_idx_0': 0.969089686870575, 'val_MRR_@10/dataloader_idx_0': 0.969089686870575, 'val_MRR_@20/dataloader_idx_0': 0.969089686870575, 'val_loss/dataloader_idx_1': 0.23037678003311157, 'val_Precision_@5/dataloader_idx_1': 0.1367187649011612, 'val_Precision_@10/dataloader_idx_1': 0.07941576838493347, 'val_Precision_@20/dataloader_idx_1': 0.04414911940693855, 'val_Recall_@5/dataloader_idx_1': 0.68359375, 'val_Recall_@10/dataloader_idx_1': 0.7941576242446899, 'val_Recall_@20/dataloader_idx_1': 0.8829823136329651, 'val_F1_@5/dataloader_idx_1': 0.20457971096038818, 'val_F1_@10/dataloader_idx_1': 0.13480627536773682, 'val_F1_@20/dataloader_idx_1': 0.08069924265146255, 'val_MAP_@5/dataloader_idx_1': 0.21445879340171814, 'val_MAP_@10/dataloader_idx_1': 0.1558171659708023, 'val_MAP_@20/dataloader_idx_1': 0.10614477097988129, 'val_NDCG_@5/dataloader_idx_1': 0.5208430290222168, 'val_NDCG_@10/dataloader_idx_1': 0.5567768216133118, 'val_NDCG_@20/dataloader_idx_1': 0.5792975425720215, 'val_MRR_@5/dataloader_idx_1': 0.4665902554988861, 'val_MRR_@10/dataloader_idx_1': 0.4815256595611572, 'val_MRR_@20/dataloader_idx_1': 0.48773816227912903, 'train_loss': 0.2164555788040161, 'train_Precision_@5': 0.20000000298023224, 'train_Precision_@10': 0.10000000149011612, 'train_Precision_@20': 0.05000000074505806, 'train_Recall_@5': 1.0, 'train_Recall_@10': 1.0, 'train_Recall_@20': 1.0, 'train_F1_@5': 0.3333330750465393, 'train_F1_@10': 0.18181805312633514, 'train_F1_@20': 0.09523805230855942, 'train_MAP_@5': 0.4493888318538666, 'train_MAP_@10': 0.2892579436302185, 'train_MAP_@20': 0.17806753516197205, 'train_NDCG_@5': 0.9865699410438538, 'train_NDCG_@10': 0.9865699410438538, 'train_NDCG_@20': 0.9865699410438538, 'train_MRR_@5': 0.9818055629730225, 'train_MRR_@10': 0.9818055629730225, 'train_MRR_@20': 0.9818055629730225, 'epoch': 20, 'step': 483},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00000_0_model_optimizer_params_lr=0.0550,model_rec_model_dropout_input=0.2770,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=Checkpoint(filesystem=local, path=/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00000_0_model_optimizer_params_lr=0.0550,model_rec_model_dropout_input=0.2770,model_rec_model_num_layers=1_2024-12-24_14-59-31/checkpoint_000020)
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00001_1_model_optimizer_params_lr=0.0137,model_rec_model_dropout_input=0.2130,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00002_2_model_optimizer_params_lr=0.0845,model_rec_model_dropout_input=0.2659,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00003_3_model_optimizer_params_lr=0.0389,model_rec_model_dropout_input=0.0138,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00004_4_model_optimizer_params_lr=0.0635,model_rec_model_dropout_input=0.3738,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00005_5_model_optimizer_params_lr=0.0384,model_rec_model_dropout_input=0.3373,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00006_6_model_optimizer_params_lr=0.0865,model_rec_model_dropout_input=0.3490,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00007_7_model_optimizer_params_lr=0.0992,model_rec_model_dropout_input=0.2504,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00008_8_model_optimizer_params_lr=0.0642,model_rec_model_dropout_input=0.1374,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00009_9_model_optimizer_params_lr=0.0461,model_rec_model_dropout_input=0.2846,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00010_10_model_optimizer_params_lr=0.0819,model_rec_model_dropout_input=0.3535,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00011_11_model_optimizer_params_lr=0.0177,model_rec_model_dropout_input=0.0716,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00012_12_model_optimizer_params_lr=0.0650,model_rec_model_dropout_input=0.0249,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00013_13_model_optimizer_params_lr=0.0736,model_rec_model_dropout_input=0.2145,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00014_14_model_optimizer_params_lr=0.0963,model_rec_model_dropout_input=0.0104,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00015_15_model_optimizer_params_lr=0.0621,model_rec_model_dropout_input=0.1346,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00016_16_model_optimizer_params_lr=0.0924,model_rec_model_dropout_input=0.4829,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00017_17_model_optimizer_params_lr=0.0696,model_rec_model_dropout_input=0.3720,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00018_18_model_optimizer_params_lr=0.0920,model_rec_model_dropout_input=0.1910,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00019_19_model_optimizer_params_lr=0.0966,model_rec_model_dropout_input=0.4618,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00020_20_model_optimizer_params_lr=0.0352,model_rec_model_dropout_input=0.1885,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00021_21_model_optimizer_params_lr=0.0384,model_rec_model_dropout_input=0.1742,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00022_22_model_optimizer_params_lr=0.0785,model_rec_model_dropout_input=0.4594,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00023_23_model_optimizer_params_lr=0.0048,model_rec_model_dropout_input=0.0505,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00024_24_model_optimizer_params_lr=0.0229,model_rec_model_dropout_input=0.4486,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00025_25_model_optimizer_params_lr=0.0291,model_rec_model_dropout_input=0.4657,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00026_26_model_optimizer_params_lr=0.0997,model_rec_model_dropout_input=0.4451,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00027_27_model_optimizer_params_lr=0.0861,model_rec_model_dropout_input=0.1247,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00028_28_model_optimizer_params_lr=0.0116,model_rec_model_dropout_input=0.4305,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00029_29_model_optimizer_params_lr=0.0279,model_rec_model_dropout_input=0.0682,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00030_30_model_optimizer_params_lr=0.0555,model_rec_model_dropout_input=0.2957,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00031_31_model_optimizer_params_lr=0.0924,model_rec_model_dropout_input=0.1669,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00032_32_model_optimizer_params_lr=0.0195,model_rec_model_dropout_input=0.4945,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00033_33_model_optimizer_params_lr=0.0094,model_rec_model_dropout_input=0.2043,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00034_34_model_optimizer_params_lr=0.0441,model_rec_model_dropout_input=0.2075,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00035_35_model_optimizer_params_lr=0.0961,model_rec_model_dropout_input=0.2712,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00036_36_model_optimizer_params_lr=0.0272,model_rec_model_dropout_input=0.0364,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00037_37_model_optimizer_params_lr=0.0312,model_rec_model_dropout_input=0.1910,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00038_38_model_optimizer_params_lr=0.0876,model_rec_model_dropout_input=0.1486,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00039_39_model_optimizer_params_lr=0.0234,model_rec_model_dropout_input=0.4634,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00040_40_model_optimizer_params_lr=0.0498,model_rec_model_dropout_input=0.0553,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00041_41_model_optimizer_params_lr=0.0042,model_rec_model_dropout_input=0.2454,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00042_42_model_optimizer_params_lr=0.0571,model_rec_model_dropout_input=0.0188,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00043_43_model_optimizer_params_lr=0.0248,model_rec_model_dropout_input=0.4193,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00044_44_model_optimizer_params_lr=0.0212,model_rec_model_dropout_input=0.1250,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00045_45_model_optimizer_params_lr=0.0769,model_rec_model_dropout_input=0.3512,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00046_46_model_optimizer_params_lr=0.0001,model_rec_model_dropout_input=0.2893,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00047_47_model_optimizer_params_lr=0.0031,model_rec_model_dropout_input=0.4116,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00048_48_model_optimizer_params_lr=0.0961,model_rec_model_dropout_input=0.2546,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00049_49_model_optimizer_params_lr=0.0552,model_rec_model_dropout_input=0.1694,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00050_50_model_optimizer_params_lr=0.0043,model_rec_model_dropout_input=0.3193,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00051_51_model_optimizer_params_lr=0.0870,model_rec_model_dropout_input=0.2770,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00052_52_model_optimizer_params_lr=0.0336,model_rec_model_dropout_input=0.4579,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00053_53_model_optimizer_params_lr=0.0619,model_rec_model_dropout_input=0.3350,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00054_54_model_optimizer_params_lr=0.0135,model_rec_model_dropout_input=0.2884,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00055_55_model_optimizer_params_lr=0.0233,model_rec_model_dropout_input=0.0224,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00056_56_model_optimizer_params_lr=0.0185,model_rec_model_dropout_input=0.2520,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00057_57_model_optimizer_params_lr=0.0936,model_rec_model_dropout_input=0.1998,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00058_58_model_optimizer_params_lr=0.0209,model_rec_model_dropout_input=0.4174,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00059_59_model_optimizer_params_lr=0.0621,model_rec_model_dropout_input=0.3077,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00060_60_model_optimizer_params_lr=0.0497,model_rec_model_dropout_input=0.2043,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00061_61_model_optimizer_params_lr=0.0430,model_rec_model_dropout_input=0.4373,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00062_62_model_optimizer_params_lr=0.0167,model_rec_model_dropout_input=0.1520,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00063_63_model_optimizer_params_lr=0.0137,model_rec_model_dropout_input=0.3553,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00064_64_model_optimizer_params_lr=0.0072,model_rec_model_dropout_input=0.4912,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00065_65_model_optimizer_params_lr=0.0388,model_rec_model_dropout_input=0.2372,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00066_66_model_optimizer_params_lr=0.0063,model_rec_model_dropout_input=0.1962,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00067_67_model_optimizer_params_lr=0.0360,model_rec_model_dropout_input=0.0894,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00068_68_model_optimizer_params_lr=0.0146,model_rec_model_dropout_input=0.3636,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00069_69_model_optimizer_params_lr=0.0981,model_rec_model_dropout_input=0.2121,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00070_70_model_optimizer_params_lr=0.0131,model_rec_model_dropout_input=0.4326,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00071_71_model_optimizer_params_lr=0.0541,model_rec_model_dropout_input=0.0318,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00072_72_model_optimizer_params_lr=0.0854,model_rec_model_dropout_input=0.1848,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00073_73_model_optimizer_params_lr=0.0054,model_rec_model_dropout_input=0.3636,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00074_74_model_optimizer_params_lr=0.0051,model_rec_model_dropout_input=0.2949,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00075_75_model_optimizer_params_lr=0.0186,model_rec_model_dropout_input=0.4190,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00076_76_model_optimizer_params_lr=0.0599,model_rec_model_dropout_input=0.2304,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00077_77_model_optimizer_params_lr=0.0391,model_rec_model_dropout_input=0.2419,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00078_78_model_optimizer_params_lr=0.0455,model_rec_model_dropout_input=0.0012,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00079_79_model_optimizer_params_lr=0.0768,model_rec_model_dropout_input=0.3510,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00080_80_model_optimizer_params_lr=0.0395,model_rec_model_dropout_input=0.2510,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00081_81_model_optimizer_params_lr=0.0825,model_rec_model_dropout_input=0.3788,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00082_82_model_optimizer_params_lr=0.0629,model_rec_model_dropout_input=0.3916,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00083_83_model_optimizer_params_lr=0.0598,model_rec_model_dropout_input=0.4718,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00084_84_model_optimizer_params_lr=0.0928,model_rec_model_dropout_input=0.0228,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00085_85_model_optimizer_params_lr=0.0105,model_rec_model_dropout_input=0.1331,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00086_86_model_optimizer_params_lr=0.0730,model_rec_model_dropout_input=0.1247,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00087_87_model_optimizer_params_lr=0.0901,model_rec_model_dropout_input=0.2421,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00088_88_model_optimizer_params_lr=0.0138,model_rec_model_dropout_input=0.3578,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00089_89_model_optimizer_params_lr=0.0808,model_rec_model_dropout_input=0.3651,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00090_90_model_optimizer_params_lr=0.0675,model_rec_model_dropout_input=0.3243,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00091_91_model_optimizer_params_lr=0.0714,model_rec_model_dropout_input=0.4400,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00092_92_model_optimizer_params_lr=0.0674,model_rec_model_dropout_input=0.3524,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00093_93_model_optimizer_params_lr=0.0865,model_rec_model_dropout_input=0.2451,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00094_94_model_optimizer_params_lr=0.0200,model_rec_model_dropout_input=0.0252,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00095_95_model_optimizer_params_lr=0.0622,model_rec_model_dropout_input=0.1190,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00096_96_model_optimizer_params_lr=0.0675,model_rec_model_dropout_input=0.0535,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00097_97_model_optimizer_params_lr=0.0653,model_rec_model_dropout_input=0.3648,model_rec_model_num_layers=2_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00098_98_model_optimizer_params_lr=0.0481,model_rec_model_dropout_input=0.0995,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   ),
#   Result(
#     metrics={},
#     path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00099_99_model_optimizer_params_lr=0.0169,model_rec_model_dropout_input=0.4525,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#     filesystem='local',
#     checkpoint=None
#   )
# ]>

# %%
results.get_best_result(metric="val_NDCG_@10/dataloader_idx_0", mode="max")
# Out:
# Result(
#   metrics={'val_loss/dataloader_idx_0': 0.3252166211605072, 'val_Precision_@5/dataloader_idx_0': 0.20000000298023224, 'val_Precision_@10/dataloader_idx_0': 0.10000000149011612, 'val_Precision_@20/dataloader_idx_0': 0.05000000074505806, 'val_Recall_@5/dataloader_idx_0': 1.0, 'val_Recall_@10/dataloader_idx_0': 1.0, 'val_Recall_@20/dataloader_idx_0': 1.0, 'val_F1_@5/dataloader_idx_0': 0.33333075046539307, 'val_F1_@10/dataloader_idx_0': 0.18181663751602173, 'val_F1_@20/dataloader_idx_0': 0.09523725509643555, 'val_MAP_@5/dataloader_idx_0': 0.44430258870124817, 'val_MAP_@10/dataloader_idx_0': 0.2867147624492645, 'val_MAP_@20/dataloader_idx_0': 0.17679595947265625, 'val_NDCG_@5/dataloader_idx_0': 0.9771838784217834, 'val_NDCG_@10/dataloader_idx_0': 0.9771838784217834, 'val_NDCG_@20/dataloader_idx_0': 0.9771838784217834, 'val_MRR_@5/dataloader_idx_0': 0.969089686870575, 'val_MRR_@10/dataloader_idx_0': 0.969089686870575, 'val_MRR_@20/dataloader_idx_0': 0.969089686870575, 'val_loss/dataloader_idx_1': 0.23037678003311157, 'val_Precision_@5/dataloader_idx_1': 0.1367187649011612, 'val_Precision_@10/dataloader_idx_1': 0.07941576838493347, 'val_Precision_@20/dataloader_idx_1': 0.04414911940693855, 'val_Recall_@5/dataloader_idx_1': 0.68359375, 'val_Recall_@10/dataloader_idx_1': 0.7941576242446899, 'val_Recall_@20/dataloader_idx_1': 0.8829823136329651, 'val_F1_@5/dataloader_idx_1': 0.20457971096038818, 'val_F1_@10/dataloader_idx_1': 0.13480627536773682, 'val_F1_@20/dataloader_idx_1': 0.08069924265146255, 'val_MAP_@5/dataloader_idx_1': 0.21445879340171814, 'val_MAP_@10/dataloader_idx_1': 0.1558171659708023, 'val_MAP_@20/dataloader_idx_1': 0.10614477097988129, 'val_NDCG_@5/dataloader_idx_1': 0.5208430290222168, 'val_NDCG_@10/dataloader_idx_1': 0.5567768216133118, 'val_NDCG_@20/dataloader_idx_1': 0.5792975425720215, 'val_MRR_@5/dataloader_idx_1': 0.4665902554988861, 'val_MRR_@10/dataloader_idx_1': 0.4815256595611572, 'val_MRR_@20/dataloader_idx_1': 0.48773816227912903, 'train_loss': 0.2164555788040161, 'train_Precision_@5': 0.20000000298023224, 'train_Precision_@10': 0.10000000149011612, 'train_Precision_@20': 0.05000000074505806, 'train_Recall_@5': 1.0, 'train_Recall_@10': 1.0, 'train_Recall_@20': 1.0, 'train_F1_@5': 0.3333330750465393, 'train_F1_@10': 0.18181805312633514, 'train_F1_@20': 0.09523805230855942, 'train_MAP_@5': 0.4493888318538666, 'train_MAP_@10': 0.2892579436302185, 'train_MAP_@20': 0.17806753516197205, 'train_NDCG_@5': 0.9865699410438538, 'train_NDCG_@10': 0.9865699410438538, 'train_NDCG_@20': 0.9865699410438538, 'train_MRR_@5': 0.9818055629730225, 'train_MRR_@10': 0.9818055629730225, 'train_MRR_@20': 0.9818055629730225, 'epoch': 20, 'step': 483},
#   path='/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00000_0_model_optimizer_params_lr=0.0550,model_rec_model_dropout_input=0.2770,model_rec_model_num_layers=1_2024-12-24_14-59-31',
#   filesystem='local',
#   checkpoint=Checkpoint(filesystem=local, path=/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00000_0_model_optimizer_params_lr=0.0550,model_rec_model_dropout_input=0.2770,model_rec_model_num_layers=1_2024-12-24_14-59-31/checkpoint_000020)
# )

# %%
#Problems with parallel execution:
# May generate the same experiment id (very unlikely)
### By default, there are N = 16^62 possible experiment ids
### L = already run experiments
### M = N - L possible experiment ids
### If generating K experiment ids concurrently, probability is sti
# TODO: reuse already run experiments, --> if using time budget, sleep for previous run-time (for fairness in comparison)
# Out:
# (RayTrainWorker pid=2061042)
# Validation DataLoader 1:  91%|█████████▏| 21/23 [00:00<00:00, 71.93it/s]
# Validation DataLoader 1:  96%|█████████▌| 22/23 [00:00<00:00, 72.33it/s]
# Validation DataLoader 1: 100%|██████████| 23/23 [00:00<00:00, 72.72it/s]
# Epoch 22:   0%|          | 0/23 [00:00<?, ?it/s, v_num=0]
# (RayTrainWorker pid=2061041) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/user/ray_results/TorchTrainer_2024-12-24_14-59-29/TorchTrainer_4c2f9_00000_0_model_optimizer_params_lr=0.0550,model_rec_model_dropout_input=0.2770,model_rec_model_num_layers=1_2024-12-24_14-59-31/checkpoint_000021)
